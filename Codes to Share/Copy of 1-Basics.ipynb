# %%
#%cd drive/MyDrive/HandonTest/DataScienceProject/BootCamp/DataSets/
#%ls
# Out:
# /content/drive/MyDrive/HandonTest/DataScienceProject/BootCamp/DataSets
# BankChurners.csv  BasicAndplot.txt  country_vaccinations.csv  Future50.csv

# %%
#Load the data in data fram df from csv file
df = pd.read_csv('BankChurners.csv')
#Print the df
df

# %%
#Print the Col headings
df.columns

# %%
#Find type of data
df.info()

# %%
df.dtypes

# %%
#Find missing values
df.isnull()

# %%
#It tell how many misising values are there in a col 
df.isnull().sum()

# %%
#Fill Null values 
#Fill by 0
df.fillna(0)

# %%
#Fill by Mean
df.fillna(df.mean())

# %%
#Drop null values
df1=df.dropna()
df1
df1.isnull()
